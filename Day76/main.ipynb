# %%
import pandas as pd
import plotly.express as px

# %%
df_apps = pd.read_csv('apps.csv')

# %%
columns = df_apps.shape[1]
rows = df_apps.shape[0]
f'It has {columns} columns and {rows} rows.'
# Out:
# 'It has 12 columns and 10841 rows.'

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                                     App            Category  \
# 5961  BestCam Selfie-selfie, beauty camera, photo ed...              BEAUTY
# 3616                                           AU Spark              FAMILY
# 1768                                Endurance Lifestyle              EVENTS
# 9705                        Asteroids 3D live wallpaper     PERSONALIZATION
# 6917  Running Weight Loss Walking Jogging Hiking FITAPP  HEALTH_AND_FITNESS
#
#       Rating  Reviews  Size_MBs    Installs  Type Price Content_Rating  \
# 5961     3.9     1739      21.0     500,000  Free     0       Everyone
# 3616     3.7      681       8.2      10,000  Free     0       Everyone
# 1768     4.6        7       3.8         500  Free     0           Teen
# 9705     4.1   157495       6.4  10,000,000  Free     0       Everyone
# 6917     4.4    20812       8.8   1,000,000  Free     0           Teen
#
#                 Genres    Last_Updated         Android_Ver
# ...

# %%
df_apps.drop(columns=['Last_Updated', 'Android_Ver'], inplace=True)
df_apps
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME     4.5
# 10837                                Subway Surfers             GAME     4.5
# 10838                                Subway Surfers             GAME     4.5
# 10839                                Subway Surfers             GAME     4.5
# 10840                                Subway Surfers             GAME     4.5
#
# ...

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean
# Out:
#                                                    App Category  Rating  \
# 21                                 KBA-EZ Health Guide  MEDICAL     5.0
# 28                                            Ra Ga Ba     GAME     5.0
# 47                                             Mu.F.O.     GAME     5.0
# 82                                    Brick Breaker BR     GAME     5.0
# 99     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL     5.0
# ...                                                ...      ...     ...
# 10836                                   Subway Surfers     GAME     4.5
# 10837                                   Subway Surfers     GAME     4.5
# 10838                                   Subway Surfers     GAME     4.5
# 10839                                   Subway Surfers     GAME     4.5
# 10840                                   Subway Surfers     GAME     4.5
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres
# ...

# %%
df_apps_clean.duplicated().value_counts()
# Out:
# False    8891
# True      476
# Name: count, dtype: int64

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'])
df_apps_clean.duplicated().value_counts()
# Out:
# False    8199
# Name: count, dtype: int64

# %%
df_apps_clean.sort_values('Rating', ascending=False).head(25)
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 1230                                      Sway Medical             MEDICAL
# 1227                                 AJ Men's Grooming           LIFESTYLE
# 1224                                    FK Dedinje BGD              SPORTS
# 1223                                   CB VIDEO VISION         PHOTOGRAPHY
# 1222                        Beacon Baptist Jupiter, FL           LIFESTYLE
# 1214                                    BV Mobile Apps        PRODUCTIVITY
# 2680                               Florida Wildflowers              FAMILY
# 1206                                      ADS-B Driver               TOOLS
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News              COMICS
# 1183                       Railroad Radio Vancouver BC              FAMILY
# ...

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False).head(14)
# Out:
#                                                     App            Category  \
# 9942                     Talking Babsy Baby: Baby Games           LIFESTYLE
# 10687                            Hungry Shark Evolution                GAME
# 9943                              Miami crime simulator                GAME
# 9944                       Gangster Town: Vice District              FAMILY
# 3144                                         Vi Trainer  HEALTH_AND_FITNESS
# 9945                                    Ultimate Tennis              SPORTS
# 7926                                          Post Bank             FINANCE
# 7927                        The Walking Dead: Our World                GAME
# 7928                      Stickman Legends: Shadow Wars                GAME
# 4176   Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 1795                               Navi Radiography Pro             MEDICAL
# ...

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %%
ratings = df_apps['Content_Rating'].value_counts()
ratings
# Out:
# Content_Rating
# Everyone           8715
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, title='Content Rating', names=ratings.index, hole=0.6)
fig.update_traces(textposition='inside', textfont_size=15, textinfo='percent')
fig.show()

# %%
df_apps_clean['Installs'] = df_apps_clean['Installs'].astype(str).str.replace(',', '')
df_apps_clean['Installs'] = pd.to_numeric(df_apps_clean['Installs'])
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
# C:\Users\PCWARE\AppData\Local\Temp\ipykernel_18944\235537786.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\PCWARE\AppData\Local\Temp\ipykernel_18944\235537786.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# ...

# %%
df_apps_clean['Price'].describe()
# Out:
# count     8199
# unique      73
# top          0
# freq      7595
# Name: Price, dtype: object

# %%
df_apps_clean['Price'] = df_apps_clean['Price'].astype(str).str.replace('$', '')
df_apps_clean['Price'] = pd.to_numeric(df_apps_clean['Price'])
# Out:
# C:\Users\PCWARE\AppData\Local\Temp\ipykernel_18944\1993443156.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\PCWARE\AppData\Local\Temp\ipykernel_18944\1993443156.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean.sort_values('Price', ascending=False).head(20)
# Out:
#                                  App   Category  Rating  Reviews   Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.300000
# 2461              I AM RICH PRO PLUS    FINANCE     4.0       36  41.000000
# 4606               I Am Rich Premium    FINANCE     4.1     1867   4.700000
# 3145              I am rich(premium)    FINANCE     3.5      472   0.942383
# 3554                      💎 I'm rich  LIFESTYLE     3.8      718  26.000000
# 5765                       I am rich  LIFESTYLE     3.8     3547   1.800000
# 1946  I am rich (Most expensive app)    FINANCE     4.1      129   2.700000
# 2775                   I Am Rich Pro     FAMILY     4.4      201   2.700000
# 3221                  I am Rich Plus     FAMILY     4.0      856   8.700000
# 3114                       I am Rich    FINANCE     4.3      180   3.800000
# 1331          most expensive app (H)     FAMILY     4.3        6   1.500000
# ...

# %%
df_apps_clean = df_apps_clean[df_apps_clean['Price']<250]

# %%
df_apps_clean.sort_values('Price', ascending=False)
# Out:
#                                App   Category  Rating   Reviews  Size_MBs  \
# 2281     Vargo Anesthesia Mega App    MEDICAL     4.6        92      32.0
# 1407                  LTC AS Legal    MEDICAL     4.0         6       1.3
# 2629              I am Rich Person  LIFESTYLE     4.2       134       1.8
# 2481       A Manual of Acupuncture    MEDICAL     3.5       214      68.0
# 2463            PTA Content Master    MEDICAL     4.2        64      41.0
# ...                            ...        ...     ...       ...       ...
# 4508   myAir™ for Air10™ by ResMed    MEDICAL     3.7       236      18.0
# 4507                 AK Math Coach     FAMILY     3.6       283      18.0
# 4506          Forgotten Hill: Fall       GAME     4.4      1063      18.0
# 4505                AE Video Poker       GAME     4.0       721      18.0
# 10835               Subway Surfers       GAME     4.5  27722264      76.0
#
#          Installs  Type  Price Content_Rating     Genres
# ...

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean['Price'] * df_apps_clean['Installs']

# %%
df_apps_clean.sort_values('Revenue_Estimate', ascending=False).head(10).value_counts('Category')
# Out:
# Category
# GAME           4
# FAMILY         3
# LIFESTYLE      1
# PHOTOGRAPHY    1
# WEATHER        1
# Name: count, dtype: int64

# %%
df_apps_clean['Category'].nunique()
# Out:
# 33

# %%
top_category = {'App': df_apps_clean['Category'].value_counts()}
category_count_df = pd.DataFrame(top_category)
category_count_df
# Out:
#                       App
# Category
# FAMILY               1606
# GAME                  910
# TOOLS                 719
# PRODUCTIVITY          301
# PERSONALIZATION       298
# LIFESTYLE             297
# FINANCE               296
# MEDICAL               292
# PHOTOGRAPHY           263
# BUSINESS              262
# SPORTS                260
# COMMUNICATION         257
# HEALTH_AND_FITNESS    243
# NEWS_AND_MAGAZINES    204
# SOCIAL                203
# TRAVEL_AND_LOCAL      187
# SHOPPING              180
# BOOKS_AND_REFERENCE   169
# VIDEO_PLAYERS         148
# DATING                134
# EDUCATION             118
# MAPS_AND_NAVIGATION   118
# ENTERTAINMENT         102
# FOOD_AND_DRINK         94
# AUTO_AND_VEHICLES      73
# WEATHER                72
# LIBRARIES_AND_DEMO     64
# HOUSE_AND_HOME         62
# ART_AND_DESIGN         61
# COMICS                 54
# PARENTING              50
# EVENTS                 45
# BEAUTY                 42

# %%
bar = px.bar(x=top_10_category.index, y=top_10_category.values)
bar.show()

# %%
category_intalls = df_apps_clean.groupby('Category').agg({'Installs':pd.Series.sum})
category_intalls.sort_values("Installs", ascending=True, inplace=True)

# %%
category_intalls
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 39162676
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97082000
# ART_AND_DESIGN         114233100
# DATING                 140912410
# FOOD_AND_DRINK         211677750
# EDUCATION              352852000
# WEATHER                361096500
# FINANCE                455249400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503611120
# BUSINESS               692018120
# SPORTS                1096431465
# HEALTH_AND_FITNESS    1134006220
# SHOPPING              1400331540
# PERSONALIZATION       1532352930
# BOOKS_AND_REFERENCE   1665791655
# ENTERTAINMENT         2113660000
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3916897200
# FAMILY                4437554490
# ...

# %%
h_bar = px.bar(y=category_intalls.index, x=category_intalls['Installs'])
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()

# %%
scatter_df = pd.merge(category_count_df, category_intalls, on='Category')

# %%
scatter = px.scatter(scatter_df, x='App', y='Installs', title='Category Concentration', size='App', color='Installs', hover_name=scatter_df.index)
scatter.update_layout(xaxis_title='Number of Apps(Lower = More concentrated)', yaxis_title='Installs')
scatter.show()

# %%
stack = df_apps_clean['Genres'].str.split(';', expand=True).stack()
num_genres = stack.value_counts()
num_genres
# Out:
# Tools                      719
# Education                  587
# Entertainment              498
# Action                     304
# Productivity               301
# Personalization            298
# Lifestyle                  298
# Finance                    296
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# ...

# %%
bar = px.bar(x=num_genres.index[:15], y=num_genres.values[:15], title='Top Genres', hover_name=num_genres.index[:15], color=num_genres.values[:15])
bar.update_layout(xaxis_title='Genre', yaxis_title='Number of Apps', coloraxis_showscale=False)
bar.show()

# %%
free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid = pd.DataFrame(free_vs_paid)

# %%
df_free_vs_paid
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
bar = px.bar(df_free_vs_paid, x='Category', y='App', title='Free vs Paid Apps by Category', color='Type', barmode='group')
bar.update_layout(xaxis_title='Category', yaxis_title='Number of Apps', xaxis={'categoryorder':'total descending'}, yaxis=dict(type='log'))
bar.show()

# %%
box = px.box(df_apps_clean, x='Type', y='Installs', color='Type', title='How many Downloads are Paid Apps Giving up?')
box.update_layout(yaxis=dict(type='log'))
box.show()

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps, x='Category', y='Revenue_Estimate', title='How Much Can Paid Apps Earn?')
box.update_layout(yaxis=dict(type='log'), xaxis={'categoryorder': 'min ascending'})
box.show()

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps, x='Category', y='Revenue_Estimate', title='How Much Can Paid Apps Earn?')
box.update_layout(yaxis=dict(type='log'), xaxis={'categoryorder': 'max descending'})
box.show()
